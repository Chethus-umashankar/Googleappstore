# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#importing dataset
py=pd.read_csv('Apps_data+(1).csv')
py
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Checking first 15 rows
py.head(15)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
#Shape of data
py.shape
# Out:
# (10841, 13)

# %%
#Info of data
py.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#Summary statistics of data
py.describe(include='object')
# Out:
#            App Category Reviews                Size    Installs   Type  Price  \
# count    10841    10841   10841               10841       10841  10840  10841
# unique    9660       34    6002                 462          22      3     93
# top     ROBLOX   FAMILY       0  Varies with device  1,000,000+   Free      0
# freq         9     1972     596                1695        1579  10039  10040
#
#        Content Rating Genres    Last Updated         Current Ver Android Ver
# count           10840  10841           10841               10833       10838
# unique              6    120            1378                2832          33
# top          Everyone  Tools  August 3, 2018  Varies with device  4.1 and up
# freq             8714    842             326                1459        2451

# %%
py.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
#Checking duplicates
duplicates=py.duplicated()
duplicates.sum()
# Out:
# 483

# %%
#Dropping duplicates
py.drop_duplicates(inplace=True)

# %%
py.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
#Here '1.9' is a unwanted category,so locating with label
py.loc[py['Category']=='1.9']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
py.drop([10472],inplace=True)

# %%
#Checking for missing values
py['Rating'].isnull().sum()
# Out:
# 1465

# %%
#Dropping missing values
py.dropna(axis=0,inplace=True)

# %%
#Replacing rating greater than 3.5 as high,and rest as low
py['Rating_category']=np.where(py['Rating']>3.5,'High','Low')

# %%
#Checking for unique value of new column Rating_category
py['Rating_category'].unique()
# Out:
# array(['High', 'Low'], dtype=object)

# %%
#Checking distribution of Rating category using barplot and distplot
py['Rating_category'].value_counts().plot(kind='bar',rot=0)
# Out:
# <AxesSubplot:>

# %%
sns.displot(py["Rating_category"], kde=True)
plt.show()

# %%
#checking datatypes of all columns
py.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews             object
# Size                object
# Installs            object
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Rating_category     object
# dtype: object

# %%
#converting datatype as int
py['Reviews']=py['Reviews'].astype(int)

# %%
py.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews              int32
# Size                object
# Installs            object
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Rating_category     object
# dtype: object

# %%
#Checking for outliers in Reviews using boxplot
# %matplotlib inline

plt.figure(figsize=(4,4))
sns.boxplot(py['Reviews'])
# Out:
# <AxesSubplot:xlabel='Reviews'>

# %%
#Outliers are found so converting the distribution to log transformation
py['Reviews']=np.log(py['Reviews'])

# %%
plt.figure(figsize=(4,4))
sns.boxplot(py['Reviews'])
# Out:
# <AxesSubplot:xlabel='Reviews'>

# %%
#Checking for unique values
py['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '5.5M', '17M', '39M', '31M',
#        '4.2M', '23M', '6.0M', '6.1M', '4.6M', '9.2M', '5.2M', '11M',
#        '24M', 'Varies with device', '9.4M', '15M', '10M', '1.2M', '26M',
#        '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k', '3.6M', '5.7M',
#        '8.6M', '2.4M', '27M', '2.7M', '2.5M', '7.0M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '22M', '6.4M', '3.2M', '8.2M', '4.9M', '9.5M', '5.0M',
#        '5.9M', '13M', '73M', '6.8M', '3.5M', '4.0M', '2.3M', '2.1M',
#        '42M', '9.1M', '55M', '23k', '7.3M', '6.5M', '1.5M', '7.5M', '51M',
#        '41M', '48M', '8.5M', '46M', '8.3M', '4.3M', '4.7M', '3.3M', '40M',
#        '7.8M', '8.8M', '6.6M', '5.1M', '61M', '66M', '79k', '8.4M',
# ...

# %%
#Treating all the unwanted data
py['Size']=py['Size'].astype(str)
py['Size']=py['Size'].str.replace('.','')
py['Size']=py['Size'].str.replace('M','000000')
py['Size']=py['Size'].str.replace('k','000')

# %%
remve=py[py['Size']=='Varies with device'].index
py.drop(labels=remve,inplace=True)

# %%
py['Size'].unique()
# Out:
# array(['19000000', '14000000', '87000000', '25000000', '28000000',
#        '56000000', '29000000', '33000000', '31000000', '12000000',
#        '20000000', '21000000', '37000000', '55000000', '17000000',
#        '39000000', '42000000', '23000000', '60000000', '61000000',
#        '46000000', '92000000', '52000000', '11000000', '24000000',
#        '94000000', '15000000', '10000000', '26000000', '80000000',
#        '79000000', '57000000', '35000000', '54000000', '201000',
#        '36000000', '86000000', '27000000', '70000000', '16000000',
#        '34000000', '89000000', '38000000', '32000000', '18000000',
#        '22000000', '45000000', '98000000', '90000000', '67000000',
#        '30000000', '71000000', '64000000', '82000000', '49000000',
#        '95000000', '50000000', '59000000', '13000000', '73000000',
#        '68000000', '40000000', '91000000', '23000', '65000000',
#        '75000000', '51000000', '41000000', '48000000', '85000000',
# ...

# %%
#Checking for unique values
py['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000+', '500,000,000+', '100+', '500+', '10+', '1,000,000,000+',
#        '5+', '50+', '1+'], dtype=object)

# %%
#Treating all the unwanted data
py['Installs']=py['Installs'].astype(str)
py['Installs']=py['Installs'].str.replace(',','')
py['Installs']=py['Installs'].str.replace('+','')

# %%
py['Installs'].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000', '500000000',
#        '100', '500', '10', '1000000000', '5', '50', '1'], dtype=object)

# %%
py['Installs']=py['Installs'].astype(int)
py.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews            float64
# Size                object
# Installs             int32
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Rating_category     object
# dtype: object

# %%
#Treating all the unwanted data
py['Price']=py['Price'].astype(str)
py['Price']=py['Price'].str.replace('$','')
py['Price']=py['Price'].astype('float')

# %%
#Dropping unwanted columns
py=py.drop(['Rating','App','Genres','Last Updated','Current Ver','Android Ver'],axis=1)

# %%
#Replacing Rating_category column values to numeric values 
py['Rating_category']=np.where(py['Rating_category']=='High',1,0)

# %%
#Encoding categorical columns using labelencoder
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
py['Categories']=labelencoder.fit_transform(py.Category)
py['Content']=labelencoder.fit_transform(py['Content Rating'])
py['Type__']=labelencoder.fit_transform(py['Type'])

# %%
py
# Out:
#                   Category    Reviews      Size  Installs  Type  Price  \
# 0           ART_AND_DESIGN   5.068904  19000000     10000  Free    0.0
# 1           ART_AND_DESIGN   6.874198  14000000    500000  Free    0.0
# 2           ART_AND_DESIGN  11.379508  87000000   5000000  Free    0.0
# 3           ART_AND_DESIGN  12.281384  25000000  50000000  Free    0.0
# 4           ART_AND_DESIGN   6.874198  28000000    100000  Free    0.0
# ...                    ...        ...       ...       ...   ...    ...
# 10833  BOOKS_AND_REFERENCE   3.784190    619000      1000  Free    0.0
# 10834               FAMILY   1.945910  26000000       500  Free    0.0
# 10836               FAMILY   3.637586  53000000      5000  Free    0.0
# 10837               FAMILY   1.386294  36000000       100  Free    0.0
# 10840            LIFESTYLE  12.894978  19000000  10000000  Free    0.0
#
#       Content Rating  Rating_category  Categories  Content  Type__
# ...

# %%
py['Categories'].value_counts()
# Out:
# 11    1590
# 14     959
# 29     633
# 23     277
# 20     277
# 18     273
# 12     263
# 28     232
# 25     231
# 4      225
# 24     225
# 6      206
# 15     199
# 27     170
# 21     162
# 26     159
# 30     147
# 3      143
# 7      141
# 31     116
# 19      95
# 8       95
# 13      82
# 9       67
# 1       63
# 17      61
# 0       58
# 32      51
# 16      50
# 5       49
# 22      44
# 10      38
# 2       37
# Name: Categories, dtype: int64

# %%
py['Content'].value_counts()
# Out:
# 1    5952
# 4     832
# 3     332
# 2     299
# 0       2
# 5       1
# Name: Content, dtype: int64

# %%
py['Type__'].value_counts()
# Out:
# 0    6873
# 1     545
# Name: Type__, dtype: int64

# %%
py=py.drop(['Category','Type','Content Rating'],axis=1)

# %%
# Segregate the target and independent features (use Rating_high and Rating_low as the target)
X = py.drop(['Rating_category'],axis=1)
y = py['Rating_category']

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30, random_state=42)

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (5192, 7) (2226, 7)
# (5192,) (2226,)

# %%
#Standardizing entire data as question is insufficient
from sklearn.preprocessing import StandardScaler
std_scale=StandardScaler()
std_scale
# Out:
# StandardScaler()

# %%
py_scale=std_scale.fit_transform(py)
py_scale
# Out:
# array([[-0.68006597, -0.82711046, -0.1688292 , ..., -2.03790984,
#         -0.46344798, -0.28159509],
#        [-0.19675826, -1.02545329, -0.15825044, ..., -2.03790984,
#         -0.46344798, -0.28159509],
#        [ 1.0093891 ,  1.87035195, -0.06109852, ..., -2.03790984,
#         -0.46344798, -0.28159509],
#        ...,
#        [-1.06325392,  0.52162075, -0.16893715, ..., -0.68626047,
#         -0.46344798, -0.28159509],
#        [-1.66596267, -0.15274486, -0.16904294, ..., -0.68626047,
#         -0.46344798, -0.28159509],
#        [ 1.41510596, -0.82711046,  0.04684806, ...,  0.17388004,
#         -0.46344798, -0.28159509]])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
pyminmax_scaled = pd.DataFrame(scaler.fit_transform(py), columns=py.columns)
pyminmax_scaled
# Out:
#        Reviews      Size      Installs  Price  Rating_category  Categories  \
# 0     0.287682  0.189887  9.999000e-06    0.0              1.0     0.00000
# 1     0.390140  0.139880  4.999990e-04    0.0              1.0     0.00000
# 2     0.645836  0.869982  4.999999e-03    0.0              1.0     0.00000
# 3     0.697021  0.249895  5.000000e-02    0.0              1.0     0.00000
# 4     0.390140  0.279899  9.999900e-05    0.0              1.0     0.00000
# ...        ...       ...           ...    ...              ...         ...
# 7413  0.214769  0.006051  9.990000e-07    0.0              1.0     0.09375
# 7414  0.110439  0.259896  4.990000e-07    0.0              1.0     0.34375
# 7415  0.206449  0.529934  4.999000e-06    0.0              1.0     0.34375
# 7416  0.078678  0.359910  9.900000e-08    0.0              1.0     0.34375
# 7417  0.731845  0.189887  9.999999e-03    0.0              1.0     0.56250
#
#       Content  Type__
# 0         0.2     0.0
# ...
